# %%
import pandas as pd

df = pd.read_csv("https://gist.githubusercontent.com/nnbphuong/38db511db14542f3ba9ef16e69d3814c/raw/Superstore.csv")
print(df.shape)
# Out:
# (9994, 21)

# %%
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 1          2  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 2          3  CA-2017-138688  2017-06-12  2017-06-16    Second Class
# 3          4  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# 4          5  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2015-110422  2015-01-21  2015-01-23    Second Class
# 9990    9991  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9991    9992  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9992    9993  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9993    9994  CA-2018-119914  2018-05-04  2018-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.columns
# Out:
# Index(['Sales', 'Profit', 'Expenses'], dtype='object')

# %%
df['Customer Name'].str.lower()                     # 1. Lowercase
# Out:
# 0            claire gute
# 1            claire gute
# 2        darrin van huff
# 3         sean o'donnell
# 4         sean o'donnell
#               ...
# 9989    tom boeckenhauer
# 9990         dave brooks
# 9991         dave brooks
# 9992         dave brooks
# 9993        chris cortes
# Name: Customer Name, Length: 9994, dtype: object

# %%
df['Customer Name'].str.upper()                     # 2. Uppercase
# Out:
# 0            CLAIRE GUTE
# 1            CLAIRE GUTE
# 2        DARRIN VAN HUFF
# 3         SEAN O'DONNELL
# 4         SEAN O'DONNELL
#               ...
# 9989    TOM BOECKENHAUER
# 9990         DAVE BROOKS
# 9991         DAVE BROOKS
# 9992         DAVE BROOKS
# 9993        CHRIS CORTES
# Name: Customer Name, Length: 9994, dtype: object

# %%
df['Customer Name'].str.len()  #length
# Out:
# 0       11
# 1       11
# 2       15
# 3       14
# 4       14
#         ..
# 9989    16
# 9990    11
# 9991    11
# 9992    11
# 9993    12
# Name: Customer Name, Length: 9994, dtype: int64

# %%
df['Customer Name'].str.strip()  #remove spaces
# Out:
# 0            Claire Gute
# 1            Claire Gute
# 2        Darrin Van Huff
# 3         Sean O'Donnell
# 4         Sean O'Donnell
#               ...
# 9989    Tom Boeckenhauer
# 9990         Dave Brooks
# 9991         Dave Brooks
# 9992         Dave Brooks
# 9993        Chris Cortes
# Name: Customer Name, Length: 9994, dtype: object

# %%
df['City'].str.replace("Los Angeles","Ls")
# Out:
# 0             Henderson
# 1             Henderson
# 2                    Ls
# 3       Fort Lauderdale
# 4       Fort Lauderdale
#              ...
# 9989              Miami
# 9990         Costa Mesa
# 9991         Costa Mesa
# 9992         Costa Mesa
# 9993        Westminster
# Name: City, Length: 9994, dtype: object

# %%
df['Product Name'].str.contains('Chair')
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990     True
# 9991    False
# 9992    False
# 9993    False
# Name: Product Name, Length: 9994, dtype: bool

# %%
df[df['Customer Name'].str.startswith("C")]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 1          2  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 84        85  US-2018-119662  2018-11-13  2018-11-16     First Class
# 110      111  CA-2018-146780  2018-12-25  2018-12-30  Standard Class
# 111      112  CA-2017-128867  2017-11-03  2017-11-10  Standard Class
# ...      ...             ...         ...         ...             ...
# 9937    9938  CA-2017-164889  2017-06-03  2017-06-06    Second Class
# 9960    9961  CA-2018-141446  2018-09-16  2018-09-18    Second Class
# 9961    9962  CA-2016-168088  2016-03-19  2016-03-22     First Class
# 9962    9963  CA-2016-168088  2016-03-19  2016-03-22     First Class
# 9993    9994  CA-2018-119914  2018-05-04  2018-05-09    Second Class
#
#      Customer ID       Customer Name      Segment        Country  \
# 0       CG-12520         Claire Gute     Consumer  United States
# ...

# %%
df['Customer Name'].str.startswith("C")
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 9989    False
# 9990    False
# 9991    False
# 9992    False
# 9993     True
# Name: Customer Name, Length: 9994, dtype: bool

# %%
df[df['Customer Name'].str.endswith("e")]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 1          2  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 17        18  CA-2015-167164  2015-05-13  2015-05-15    Second Class
# 35        36  CA-2017-117590  2017-12-08  2017-12-10     First Class
# 36        37  CA-2017-117590  2017-12-08  2017-12-10     First Class
# ...      ...             ...         ...         ...             ...
# 9966    9967  CA-2017-146374  2017-12-05  2017-12-10    Second Class
# 9972    9973  CA-2017-130225  2017-09-11  2017-09-17  Standard Class
# 9982    9983  US-2017-157728  2017-09-22  2017-09-28  Standard Class
# 9983    9984  US-2017-157728  2017-09-22  2017-09-28  Standard Class
# 9986    9987  CA-2017-125794  2017-09-29  2017-10-03  Standard Class
#
#      Customer ID    Customer Name    Segment        Country          City  \
# ...

# %%
import pandas as pd
import numpy as np

# %%
# Sample Dataset
data = {
    'Month': ['Jan','Feb','Mar','Apr','May','Jun'],
    'Sales': [1000, 1500, 1200, 1800, 2000, 1700],
    'Profit': [200, 300, 250, 400, 500, 350],
    'Expenses': [800, 1200, 950, 1400, 1500, 1350]
}

# %%
df = pd.DataFrame(data)
df.set_index('Month', inplace=True)

# %%
data
# Out:
# {'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun'],
#  'Sales': [1000, 1500, 1200, 1800, 2000, 1700],
#  'Profit': [200, 300, 250, 400, 500, 350],
#  'Expenses': [800, 1200, 950, 1400, 1500, 1350]}

# %%
# 1️⃣ Line Plot
df['Sales'].plot(title="Line Plot - Sales Trend")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: title={'center': 'Line Plot - Sales Trend'}, xlabel='Month'>
